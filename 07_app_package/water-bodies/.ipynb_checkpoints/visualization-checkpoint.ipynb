# %%
#!pip install leafmap

# %%
# from ipyleaflet import Map, LayersControl, LayerGroup, GeoJSON
# from localtileserver import TileClient, get_leaflet_tile_layer
import leafmap.foliumap as leafmap

import pystac
import json

# %% [markdown]
# Load the JSON result listing generated by `cwltool`:

# %%
with open("/workspace/workshop/07_app_package/water-bodies/outputs/out.json") as f: 
    results = json.load(f)

# %% [markdown]
# Look for the `catalog.json` file:

# %%
for item in results["stac_catalog"]["listing"]:
    
    if item['basename'] == "catalog.json":
        catalog = pystac.read_file(item["path"])
        break

# %% [markdown]
# List the contents of the STAC Catalog

# %%
catalog.describe()
# Out:
# * <Catalog id=catalog>
#   * <Item id=S2B_10TFK_20210713_0_L2A>
#   * <Item id=S2A_10TFK_20220524_0_L2A>

# %%
m = leafmap.Map()

for item in catalog.get_all_items():
    
    m.add_raster(item.get_assets()["data"].get_absolute_href(), layer_name=item.id)

m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /srv/conda/lib/python3.7/site-packages/leafmap/common.py in check_package(name, URL)
#     153     try:
# --> 154         __import__(name.lower())
#     155     except Exception:
#
# ModuleNotFoundError: No module named 'localtileserver'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_2059822/3672930931.py in <module>
#       4 for item in catalog.get_all_items():
#       5
# ----> 6     m.add_raster(item.get_assets()["data"].get_absolute_href(), layer_name=item.id)
#       7
#       8 m
#
# /srv/conda/lib/python3.7/site-packages/leafmap/foliumap.py in add_raster(self, source, band, palette, vmin, vmax, nodata, attribution, layer_name, **kwargs)
#     399             layer_name=layer_name,
#     400             return_client=True,
# --> 401             **kwargs,
#     402         )
#     403         self.add_layer(tile_layer)
#
# /srv/conda/lib/python3.7/site-packages/leafmap/common.py in get_local_tile_layer(source, port, debug, projection, band, palette, vmin, vmax, nodata, attribution, tile_format, layer_name, return_client, **kwargs)
#    2846
#    2847     check_package(
# -> 2848         "localtileserver", URL="https://github.com/banesullivan/localtileserver"
#    2849     )
#    2850
#
# /srv/conda/lib/python3.7/site-packages/leafmap/common.py in check_package(name, URL)
#     155     except Exception:
#     156         raise ImportError(
# --> 157             f"{name} is not installed. Please install it before proceeding. {URL}"
#     158         )
#     159
#
# ImportError: localtileserver is not installed. Please install it before proceeding. https://github.com/banesullivan/localtileserver
