# %% [markdown]
# # Application Package development and testing
# ## Water Bodies detection
#
# Scenario: Alice implements the Application Package

# %% [markdown]
# ## Background
# This Application Package takes as input Copernicus Sentinel-2 data and detects water bodies by applying the *Otsu* thresholding technique on the Normalized Difference Water Index (NDWI).
#
# The NDWI is calculated with:
#
# $$
# NDWI = { (green - nir) \over (green + nir) }
# $$
#
# Typically, NDWI values of water bodies are larger than 0.2 and built-up features have positive values between 0 and 0.2. Vegetation has much smaller NDWI values, which results in distinguishing vegetation from water bodies easier.
#
# The NDWI values correspond to the following ranges:
#
# | Range       | Description                            |
# | ----------- | -------------------------------------- |
# | 0,2 - 1     | Water surface                          |
# | 0.0 - 0,2   | Flooding, humidity                     |
# | -0,3 - 0.0  | Moderate drought, non-aqueous surfaces |
# | -1 - -0.3   | Drought, non-aqueous surfaces          |
#
# To ease the determination of the water surface/non water surface, the Ostu thresholding technique is used.
#
# In the simplest form, the Otsu algorithm returns a single intensity threshold that separate pixels into two classes, foreground and background. This threshold is determined by minimizing intra-class intensity variance, or equivalently, by maximizing inter-class variance:
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/3/34/Otsu%27s_Method_Visualization.gif)

# %% [markdown]
# ## Application Workflow
# The Water Bodies detection steps are depicted below:
# ``` mermaid
# graph TB
#   A[STAC Items] --> B
#   A[STAC Items] --> C
# subgraph Process STAC item
#   B["crop(green)"] --> D[Normalized difference];
#   C["crop(nir)"] --> D[Normalized difference];
#   D --> E[Otsu threshold]
# end
#   E --> F[Create STAC]
# ```
#
# The application takes a list of Sentinel-2 STAC items references and then crops the radiometric bands `green` and `NIR` with a user-defined area of interest (AOI). Each cropped band is then used to calculate the `NDWI` and subsequently the Otsu threashold is applied to it, generating the water bodies output mask. The final step of the workflow consists on generating the STAC catalog and items for the generated results.
#
# Alice organizes the Application Package to include a macro workflow that reads the list of Sentinel-2 STAC items references, the AOI and the EPSG code. The workflow steps include i) a sub-workflow for the detection of the water bodies and ii) a step to create the STAC catalog of the generated output product(s)
#
# ![image](water_bodies.png "water-bodies")
#
# The sub-workflow applies the  `crop`, `Normalized difference`, `Otsu threshold` steps:
#
# ![image](detect_water_body.png "detect-water-body")
#
# ## Input Sentinel-2 acquisitions
# The development and test dataset is made of two Sentinel-2 acquisitions:
#
# | Acquisitions 	|Image 1                    	|Image 2                    	|
# |--------------	|---------------------------	|---------------------------	|
# | Date         	|2021-07-13                 	|2022-05-24                 	|
# | URL          	| [S2B_10TFK_20210713_0_L2A](https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A) 	| [S2A_10TFK_20220524_0_L2A](https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A) 	|
# | Quicklook    	| ![image](img_20210713.jpg) 	| ![image](img_20220504.jpg) 	|

# %% [markdown]
# ## Environments creation
#
# Each `Command Line Tool` step (`crop`, `Normalized difference`, `Otsu threshold` and `Create STAC`) runs a Python script in a dedicated environment / container.
# To generate the environments, open a new `Terminal` and execute the commands below (either one by one or all at once).
#
# **Note**: This configuration step takes around five minutes to complete.

# %%
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_test  gdal click pystac 
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_norm_diff click gdal  
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_otsu gdal scikit-image click 
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_stac click pystac python=3.9 pip && \
    /srv/conda/envs/env_stac/bin/pip install rio_stac
# !mamba clean --all -f -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.23.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['gdal', 'click', 'pystac']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# r/linux-64                                                  Using cache
# r/noarch                                                    Using cache
# [+] 0.0s
# [+] 0.1s
# pkgs/main/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/linux-64    ━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# terradue/linux-64  ━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1spkgs/main/noarch                                              No change
# pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
# pkgs/r/linux-64                                               No change
# [+] 0.2s
# terradue/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# terradue/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# eoepca/linux-64   ━━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# eoepca/noarch     ━━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.3s
# terradue/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# terradue/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# eoepca/linux-64   ━━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# eoepca/noarch     ━━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.4s
# terradue/linux-64 ━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# terradue/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# eoepca/linux-64   ━━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# eoepca/noarch     ━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.5s
# terradue/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s
# terradue/noarch   ━━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# eoepca/linux-64   ━━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# eoepca/noarch     ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3sterradue/linux-64                                             No change
# [+] 0.6s
# terradue/noarch ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# eoepca/linux-64 ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# eoepca/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4seoepca/linux-64                                               No change
# eoepca/noarch                                                 No change
# [+] 0.7s
# terradue/noarch ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5sterradue/noarch                                               No change
# Transaction
#
#   Prefix: /srv/conda/envs/env_test
#
#   Updating specs:
#
#    - gdal
#    - click
#    - pystac
#
#
#   Package                           Version  Build                Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                       0.1  conda_forge          conda-forge/linux-64     Cached
#   + _openmp_mutex                       4.5  2_gnu                conda-forge/linux-64     Cached
#   + blosc                            1.21.4  h0f2a231_0           conda-forge/linux-64     Cached
#   + boost-cpp                        1.78.0  h6582d0a_3           conda-forge/linux-64     Cached
#   + bzip2                             1.0.8  h7f98852_4           conda-forge/linux-64     Cached
#   + c-ares                           1.19.0  hd590300_0           conda-forge/linux-64     Cached
#   + ca-certificates                2023.5.7  hbcca054_0           conda-forge/linux-64     Cached
#   + cairo                            1.16.0  h35add3b_1015        conda-forge/linux-64     Cached
#   + cfitsio                           4.2.0  hd9d235c_0           conda-forge/linux-64     Cached
#   + click                             8.1.3  py311h38be061_1      conda-forge/linux-64     Cached
#   + curl                              8.1.0  h409715c_0           conda-forge/linux-64     Cached
#   + expat                             2.5.0  hcb278e6_1           conda-forge/linux-64     Cached
#   + font-ttf-dejavu-sans-mono          2.37  hab24e00_0           conda-forge/noarch       Cached
#   + font-ttf-inconsolata              3.000  h77eed37_0           conda-forge/noarch       Cached
#   + font-ttf-source-code-pro          2.038  h77eed37_0           conda-forge/noarch       Cached
#   + font-ttf-ubuntu                    0.83  hab24e00_0           conda-forge/noarch       Cached
#   + fontconfig                       2.14.2  h14ed4e7_0           conda-forge/linux-64     Cached
#   + fonts-conda-ecosystem                 1  0                    conda-forge/noarch       Cached
#   + fonts-conda-forge                     1  0                    conda-forge/noarch       Cached
#   + freetype                         2.12.1  hca18f0e_1           conda-forge/linux-64     Cached
#   + freexl                            1.0.6  h166bdaf_1           conda-forge/linux-64     Cached
#   + gdal                              3.7.0  py311h6122507_0      conda-forge/linux-64     Cached
#   + geos                             3.11.2  hcb278e6_0           conda-forge/linux-64     Cached
#   + geotiff                           1.7.1  h480ec47_8           conda-forge/linux-64     Cached
#   + gettext                          0.21.1  h27087fc_0           conda-forge/linux-64     Cached
#   + giflib                            5.2.1  h0b41bf4_3           conda-forge/linux-64     Cached
#   + hdf4                             4.2.15  h501b40f_6           conda-forge/linux-64     Cached
#   + hdf5                             1.14.0  nompi_hb72d44e_103   conda-forge/linux-64     Cached
#   + icu                                72.1  hcb278e6_0           conda-forge/linux-64     Cached
#   + json-c                             0.16  hc379101_0           conda-forge/linux-64     Cached
#   + kealib                            1.5.1  h3845be2_3           conda-forge/linux-64     Cached
#   + keyutils                          1.6.1  h166bdaf_0           conda-forge/linux-64     Cached
#   + krb5                             1.20.1  h81ceb04_0           conda-forge/linux-64     Cached
#   + lcms2                              2.15  haa2dc70_1           conda-forge/linux-64     Cached
#   + ld_impl_linux-64                   2.40  h41732ed_0           conda-forge/linux-64     Cached
#   + lerc                              4.0.0  h27087fc_0           conda-forge/linux-64     Cached
#   + libaec                            1.0.6  hcb278e6_1           conda-forge/linux-64     Cached
#   + libarchive                        3.6.2  h3d51595_0           conda-forge/linux-64     Cached
#   + libblas                           3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libcblas                          3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libcurl                           8.1.0  h409715c_0           conda-forge/linux-64     Cached
#   + libdeflate                         1.18  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libedit                    3.1.20191231  he28a2e2_2           conda-forge/linux-64     Cached
#   + libev                              4.33  h516909a_1           conda-forge/linux-64     Cached
#   + libexpat                          2.5.0  hcb278e6_1           conda-forge/linux-64     Cached
#   + libffi                            3.4.2  h7f98852_5           conda-forge/linux-64     Cached
#   + libgcc-ng                        12.2.0  h65d4601_19          conda-forge/linux-64     Cached
#   + libgdal                           3.7.0  he76be6c_0           conda-forge/linux-64     Cached
#   + libgfortran-ng                   12.2.0  h69a702a_19          conda-forge/linux-64     Cached
#   + libgfortran5                     12.2.0  h337968e_19          conda-forge/linux-64     Cached
#   + libglib                          2.76.2  hebfc3b9_0           conda-forge/linux-64     Cached
#   + libgomp                          12.2.0  h65d4601_19          conda-forge/linux-64     Cached
#   + libiconv                           1.17  h166bdaf_0           conda-forge/linux-64     Cached
#   + libjpeg-turbo                   2.1.5.1  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libkml                            1.3.0  h37653c0_1015        conda-forge/linux-64     Cached
#   + liblapack                         3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libnetcdf                         4.9.2  nompi_hdf9a29f_104   conda-forge/linux-64     Cached
#   + libnghttp2                       1.52.0  h61bc06f_0           conda-forge/linux-64     Cached
#   + libnsl                            2.0.0  h7f98852_0           conda-forge/linux-64     Cached
#   + libopenblas                      0.3.21  pthreads_h78a6416_3  conda-forge/linux-64     Cached
#   + libpng                           1.6.39  h753d276_0           conda-forge/linux-64     Cached
#   + libpq                              15.3  hbcd7760_0           conda-forge/linux-64     Cached
#   + librttopo                         1.1.0  h0d5128d_13          conda-forge/linux-64     Cached
#   + libspatialite                     5.0.1  h7d1ca68_25          conda-forge/linux-64     Cached
#   + libsqlite                        3.42.0  h2797004_0           conda-forge/linux-64     Cached
#   + libssh2                          1.10.0  hf14f497_3           conda-forge/linux-64     Cached
#   + libstdcxx-ng                     12.2.0  h46fd767_19          conda-forge/linux-64     Cached
#   + libtiff                           4.5.0  ha587672_6           conda-forge/linux-64     Cached
#   + libuuid                          2.38.1  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libwebp-base                      1.3.0  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libxcb                             1.13  h7f98852_1004        conda-forge/linux-64     Cached
#   + libxml2                          2.10.4  hfdac1af_0           conda-forge/linux-64     Cached
#   + libzip                            1.9.2  hc929e4a_1           conda-forge/linux-64     Cached
#   + libzlib                          1.2.13  h166bdaf_4           conda-forge/linux-64     Cached
#   + lz4-c                             1.9.4  hcb278e6_0           conda-forge/linux-64     Cached
#   + lzo                                2.10  h516909a_1000        conda-forge/linux-64     Cached
#   + ncurses                             6.3  h27087fc_1           conda-forge/linux-64     Cached
#   + nspr                               4.35  h27087fc_0           conda-forge/linux-64     Cached
#   + nss                                3.89  he45b914_0           conda-forge/linux-64     Cached
#   + numpy                            1.24.3  py311h64a7726_0      conda-forge/linux-64     Cached
#   + openjpeg                          2.5.0  hfec8fc6_2           conda-forge/linux-64     Cached
#   + openssl                           3.1.0  hd590300_3           conda-forge/linux-64     Cached
#   + pcre2                             10.40  hc3806b6_0           conda-forge/linux-64     Cached
#   + pip                              23.1.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pixman                           0.40.0  h36c2ea0_0           conda-forge/linux-64     Cached
#   + poppler                         23.05.0  hd18248d_1           conda-forge/linux-64     Cached
#   + poppler-data                     0.4.12  hd8ed1ab_0           conda-forge/noarch       Cached
#   + postgresql                         15.3  h814edd5_0           conda-forge/linux-64     Cached
#   + proj                              9.2.0  h8ffa02c_0           conda-forge/linux-64     Cached
#   + pthread-stubs                       0.4  h36c2ea0_1001        conda-forge/linux-64     Cached
#   + pystac                            1.7.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python                           3.11.3  h2755cc3_0_cpython   conda-forge/linux-64     Cached
#   + python-dateutil                   2.8.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python_abi                         3.11  3_cp311              conda-forge/linux-64     Cached
#   + readline                            8.2  h8228510_1           conda-forge/linux-64     Cached
#   + setuptools                       67.7.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + six                              1.16.0  pyh6c4a22f_0         conda-forge/noarch       Cached
#   + snappy                           1.1.10  h9fff704_0           conda-forge/linux-64     Cached
#   + sqlite                           3.42.0  h2c6b66d_0           conda-forge/linux-64     Cached
#   + tiledb                           2.13.2  hd532e3d_0           conda-forge/linux-64     Cached
#   + tk                               8.6.12  h27826a3_0           conda-forge/linux-64     Cached
#   + tzcode                            2023c  h0b41bf4_0           conda-forge/linux-64     Cached
#   + tzdata                            2023c  h71feb2d_0           conda-forge/noarch       Cached
#   + wheel                            0.40.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + xerces-c                          3.2.4  h8d71039_2           conda-forge/linux-64     Cached
#   + xorg-kbproto                      1.0.7  h7f98852_1002        conda-forge/linux-64     Cached
#   + xorg-libice                      1.0.10  h7f98852_0           conda-forge/linux-64     Cached
#   + xorg-libsm                        1.2.3  hd9c2040_1000        conda-forge/linux-64     Cached
#   + xorg-libx11                       1.8.4  h0b41bf4_0           conda-forge/linux-64     Cached
#   + xorg-libxau                       1.0.9  h7f98852_0           conda-forge/linux-64     Cached
#   + xorg-libxdmcp                     1.1.3  h7f98852_0           conda-forge/linux-64     Cached
#   + xorg-libxext                      1.3.4  h0b41bf4_2           conda-forge/linux-64     Cached
#   + xorg-libxrender                  0.9.10  h7f98852_1003        conda-forge/linux-64     Cached
#   + xorg-renderproto                 0.11.1  h7f98852_1002        conda-forge/linux-64     Cached
#   + xorg-xextproto                    7.3.0  h0b41bf4_1003        conda-forge/linux-64     Cached
#   + xorg-xproto                      7.0.31  h7f98852_1007        conda-forge/linux-64     Cached
#   + xz                                5.2.6  h166bdaf_0           conda-forge/linux-64     Cached
#   + zlib                             1.2.13  h166bdaf_4           conda-forge/linux-64     Cached
#   + zstd                              1.5.2  h3eb15da_6           conda-forge/linux-64     Cached
#
#   Summary:
#
#   Install: 119 packages
#
#   Total download: 0 B
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# To activate this environment, use
#
#      $ mamba activate /srv/conda/envs/env_test
#
# To deactivate an active environment, use
#
#      $ mamba deactivate
#
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.23.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['click', 'gdal']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# r/linux-64                                                  Using cache
# r/noarch                                                    Using cache
# [+] 0.0s
# [+] 0.1s
# pkgs/main/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━━━━━╸━━━━━━━━━━━━━━━╸━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/linux-64    ━━╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch      ━━━━━━╸━━━━━━━━━━━━━━━╸━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# terradue/linux-64  ━╸━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# pkgs/main/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/main/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/r/linux-64    ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/r/noarch      ━━━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.3s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s[+] 0.4s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s[+] 0.5s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s[+] 0.6s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.6s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.6s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.6s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.6s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.6s[+] 0.7s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.7s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.7s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.7s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.7s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.7s[+] 0.8s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.8s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.8s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.8s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.8s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.8s[+] 0.9s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.9s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.9s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.9s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.9s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.9s[+] 1.0s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.0s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.0s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.0s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.0s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.0s[+] 1.1s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.1s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.1s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.1s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.1s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.1s[+] 1.2s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.2s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.2s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.2s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.2s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.2s[+] 1.3s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.3s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.3s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.3s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.3s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.3s[+] 1.4s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.4s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.4s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.4s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.4s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.4s[+] 1.5s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.5s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.5s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.5s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.5s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.5s[+] 1.6s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.6s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.6s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.6s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.6s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.6s[+] 1.7s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.7s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.7s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.7s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.7s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.7s[+] 1.8s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.8s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.8s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.8s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.8s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.8s[+] 1.9s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.9s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.9s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.9s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.9s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  1.9s[+] 2.0s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.0s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.0s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.0s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.0s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.0s[+] 2.1s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.1s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.1s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.1s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.1s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.1s[+] 2.2s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.2s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.2s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.2s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.2s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.2s[+] 2.3s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.3s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.3s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.3s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.3s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.3s[+] 2.4s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.4s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.4s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.4s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.4s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.4s[+] 2.5s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.5s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.5s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.5s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.5s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.5s[+] 2.6s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.6s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.6s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.6s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.6s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.6s[+] 2.7s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.7s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.7s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.7s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.7s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.7s[+] 2.8s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.8s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.8s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.8s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.8s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.8s[+] 2.9s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.9s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.9s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.9s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.9s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  2.9s[+] 3.0s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.0s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.0s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.0s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.0s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.0s[+] 3.1s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.1s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.1s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.1s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.1s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.1s[+] 3.2s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.2s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.2s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.2s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.2s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.2s[+] 3.3s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.3s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.3s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.3s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.3s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.3s[+] 3.4s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.4s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.4s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.4s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.4s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.4s[+] 3.5s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.5s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.5s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.5s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.5s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.5s[+] 3.6s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.6s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.6s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.6s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.6s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.6s[+] 3.7s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.7s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.7s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.7s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.7s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.7s[+] 3.8s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.8s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.8s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.8s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.8s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.8s[+] 3.9s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.9s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.9s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.9s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.9s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  3.9s[+] 4.0s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.0s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.0s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.0s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.0s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.0s[+] 4.1s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.1s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.1s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.1s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.1s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.1s[+] 4.2s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.2s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.2s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.2s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.2s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.2s[+] 4.3s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.3s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.3s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.3s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.3s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.3s[+] 4.4s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.4s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.4s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.4s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.4s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.4s[+] 4.5s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.5s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.5s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.5s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.5s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.5s[+] 4.6s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.6s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.6s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.6s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.6s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.6s[+] 4.7s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.7s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.7s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.7s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.7s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.7s[+] 4.8s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.8s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.8s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.8s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.8s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.8s[+] 4.9s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.9s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.9s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.9s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.9s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  4.9s[+] 5.0s
# pkgs/main/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.0s
# pkgs/main/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.0s
# pkgs/r/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.0s
# pkgs/r/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.0s
# terradue/linux-64  ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.0spkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# pkgs/r/linux-64                                               No change
# pkgs/r/noarch                                                 No change
# [+] 5.1s
# terradue/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.1s
# terradue/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# eoepca/linux-64   ━━━━━━━╸━━━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# eoepca/noarch     ━━╸━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 5.2s
# terradue/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  5.2s
# terradue/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# eoepca/linux-64   ━━━━━━━╸━━━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# eoepca/noarch     ━━╸━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 5.3s
# terradue/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━╸━━   0.0 B /  ??.?MB @  ??.?MB/s  5.3s
# terradue/noarch   ━╸━━━━━━━━━━━━━━━╸━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# eoepca/linux-64   ━━━━━━━━╸━━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# eoepca/noarch     ━━━╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s[+] 5.4s
# terradue/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  5.4s
# terradue/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# eoepca/linux-64   ━━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# eoepca/noarch     ━━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4seoepca/noarch                                                 No change
# terradue/linux-64                                             No change
# eoepca/linux-64                                               No change
# [+] 5.5s
# terradue/noarch ━━━━━╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5sterradue/noarch                                               No change
# Transaction
#
#   Prefix: /srv/conda/envs/env_norm_diff
#
#   Updating specs:
#
#    - click
#    - gdal
#
#
#   Package                           Version  Build                Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                       0.1  conda_forge          conda-forge/linux-64     Cached
#   + _openmp_mutex                       4.5  2_gnu                conda-forge/linux-64     Cached
#   + blosc                            1.21.4  h0f2a231_0           conda-forge/linux-64     Cached
#   + boost-cpp                        1.78.0  h6582d0a_3           conda-forge/linux-64     Cached
#   + bzip2                             1.0.8  h7f98852_4           conda-forge/linux-64     Cached
#   + c-ares                           1.19.0  hd590300_0           conda-forge/linux-64     Cached
#   + ca-certificates                2023.5.7  hbcca054_0           conda-forge/linux-64     Cached
#   + cairo                            1.16.0  h35add3b_1015        conda-forge/linux-64     Cached
#   + cfitsio                           4.2.0  hd9d235c_0           conda-forge/linux-64     Cached
#   + click                             8.1.3  py311h38be061_1      conda-forge/linux-64     Cached
#   + curl                              8.1.0  h409715c_0           conda-forge/linux-64     Cached
#   + expat                             2.5.0  hcb278e6_1           conda-forge/linux-64     Cached
#   + font-ttf-dejavu-sans-mono          2.37  hab24e00_0           conda-forge/noarch       Cached
#   + font-ttf-inconsolata              3.000  h77eed37_0           conda-forge/noarch       Cached
#   + font-ttf-source-code-pro          2.038  h77eed37_0           conda-forge/noarch       Cached
#   + font-ttf-ubuntu                    0.83  hab24e00_0           conda-forge/noarch       Cached
#   + fontconfig                       2.14.2  h14ed4e7_0           conda-forge/linux-64     Cached
#   + fonts-conda-ecosystem                 1  0                    conda-forge/noarch       Cached
#   + fonts-conda-forge                     1  0                    conda-forge/noarch       Cached
#   + freetype                         2.12.1  hca18f0e_1           conda-forge/linux-64     Cached
#   + freexl                            1.0.6  h166bdaf_1           conda-forge/linux-64     Cached
#   + gdal                              3.7.0  py311h6122507_0      conda-forge/linux-64     Cached
#   + geos                             3.11.2  hcb278e6_0           conda-forge/linux-64     Cached
#   + geotiff                           1.7.1  h480ec47_8           conda-forge/linux-64     Cached
#   + gettext                          0.21.1  h27087fc_0           conda-forge/linux-64     Cached
#   + giflib                            5.2.1  h0b41bf4_3           conda-forge/linux-64     Cached
#   + hdf4                             4.2.15  h501b40f_6           conda-forge/linux-64     Cached
#   + hdf5                             1.14.0  nompi_hb72d44e_103   conda-forge/linux-64     Cached
#   + icu                                72.1  hcb278e6_0           conda-forge/linux-64     Cached
#   + json-c                             0.16  hc379101_0           conda-forge/linux-64     Cached
#   + kealib                            1.5.1  h3845be2_3           conda-forge/linux-64     Cached
#   + keyutils                          1.6.1  h166bdaf_0           conda-forge/linux-64     Cached
#   + krb5                             1.20.1  h81ceb04_0           conda-forge/linux-64     Cached
#   + lcms2                              2.15  haa2dc70_1           conda-forge/linux-64     Cached
#   + ld_impl_linux-64                   2.40  h41732ed_0           conda-forge/linux-64     Cached
#   + lerc                              4.0.0  h27087fc_0           conda-forge/linux-64     Cached
#   + libaec                            1.0.6  hcb278e6_1           conda-forge/linux-64     Cached
#   + libarchive                        3.6.2  h3d51595_0           conda-forge/linux-64     Cached
#   + libblas                           3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libcblas                          3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libcurl                           8.1.0  h409715c_0           conda-forge/linux-64     Cached
#   + libdeflate                         1.18  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libedit                    3.1.20191231  he28a2e2_2           conda-forge/linux-64     Cached
#   + libev                              4.33  h516909a_1           conda-forge/linux-64     Cached
#   + libexpat                          2.5.0  hcb278e6_1           conda-forge/linux-64     Cached
#   + libffi                            3.4.2  h7f98852_5           conda-forge/linux-64     Cached
#   + libgcc-ng                        12.2.0  h65d4601_19          conda-forge/linux-64     Cached
#   + libgdal                           3.7.0  he76be6c_0           conda-forge/linux-64     Cached
#   + libgfortran-ng                   12.2.0  h69a702a_19          conda-forge/linux-64     Cached
#   + libgfortran5                     12.2.0  h337968e_19          conda-forge/linux-64     Cached
#   + libglib                          2.76.2  hebfc3b9_0           conda-forge/linux-64     Cached
#   + libgomp                          12.2.0  h65d4601_19          conda-forge/linux-64     Cached
#   + libiconv                           1.17  h166bdaf_0           conda-forge/linux-64     Cached
#   + libjpeg-turbo                   2.1.5.1  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libkml                            1.3.0  h37653c0_1015        conda-forge/linux-64     Cached
#   + liblapack                         3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libnetcdf                         4.9.2  nompi_hdf9a29f_104   conda-forge/linux-64     Cached
#   + libnghttp2                       1.52.0  h61bc06f_0           conda-forge/linux-64     Cached
#   + libnsl                            2.0.0  h7f98852_0           conda-forge/linux-64     Cached
#   + libopenblas                      0.3.21  pthreads_h78a6416_3  conda-forge/linux-64     Cached
#   + libpng                           1.6.39  h753d276_0           conda-forge/linux-64     Cached
#   + libpq                              15.3  hbcd7760_0           conda-forge/linux-64     Cached
#   + librttopo                         1.1.0  h0d5128d_13          conda-forge/linux-64     Cached
#   + libspatialite                     5.0.1  h7d1ca68_25          conda-forge/linux-64     Cached
#   + libsqlite                        3.42.0  h2797004_0           conda-forge/linux-64     Cached
#   + libssh2                          1.10.0  hf14f497_3           conda-forge/linux-64     Cached
#   + libstdcxx-ng                     12.2.0  h46fd767_19          conda-forge/linux-64     Cached
#   + libtiff                           4.5.0  ha587672_6           conda-forge/linux-64     Cached
#   + libuuid                          2.38.1  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libwebp-base                      1.3.0  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libxcb                             1.13  h7f98852_1004        conda-forge/linux-64     Cached
#   + libxml2                          2.10.4  hfdac1af_0           conda-forge/linux-64     Cached
# ...
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.2s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.3s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.4s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.5s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.5s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.6s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.6s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.7s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.7s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.8s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.8s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 2.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     2.9s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.0s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.2s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.3s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.4s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.5s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.5s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.6s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.6s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.7s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.7s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.8s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.8s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 3.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     3.9s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.0s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.2s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.2s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.3s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.3s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.4s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.4s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.5s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.5s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.6s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.6s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.7s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.7s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.8s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.8s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 4.9s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     4.9s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 5.0s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     5.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 5.1s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B charls                     5.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0scharls                                             150.3kB @  29.1kB/s  5.2s
# [+] 5.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 150.3kB                            5.2s
# Extracting   (1) ━━━━━━━━━━━━━╸━━━━━━━━━       0 charls                     0.0s[+] 5.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 150.3kB                            5.2s
# Extracting   (1) ━━━━━━━━━━━━━━╸━━━━━━━━       0 charls                     0.1s[+] 5.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━ 150.3kB                            5.2s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       1                            0.2sPreparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# To activate this environment, use
#
#      $ mamba activate /srv/conda/envs/env_otsu
#
# To deactivate an active environment, use
#
#      $ mamba deactivate
#
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.23.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['click', 'pystac', 'python=3.9', 'pip']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# r/linux-64                                                  Using cache
# r/noarch                                                    Using cache
# [+] 0.0s
# [+] 0.1s
# pkgs/main/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/linux-64    ━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch      ━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# terradue/linux-64  ━━━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1spkgs/r/linux-64                                               No change
# pkgs/main/linux-64                                            No change
# pkgs/main/noarch                                              No change
# pkgs/r/noarch                                                 No change
# [+] 0.2s
# terradue/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# terradue/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# eoepca/linux-64   ━━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# eoepca/noarch     ━━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.3s
# terradue/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# terradue/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# eoepca/linux-64   ━━━━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# eoepca/noarch     ━━━━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1sterradue/noarch                                               No change
# [+] 0.4s
# terradue/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# eoepca/linux-64   ━━━━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# eoepca/noarch     ━━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.5s
# terradue/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s
# eoepca/linux-64   ━━━━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# eoepca/noarch     ━━━━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3sterradue/linux-64                                             No change
# [+] 0.6s
# eoepca/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s
# eoepca/noarch   ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4seoepca/noarch                                                 No change
# eoepca/linux-64                                               No change
# Transaction
#
#   Prefix: /srv/conda/envs/env_stac
#
#   Updating specs:
#
#    - click
#    - pystac
#    - python=3.9
#    - pip
#
#
#   Package              Version  Build               Channel                    Size
# ─────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex          0.1  conda_forge         conda-forge/linux-64     Cached
#   + _openmp_mutex          4.5  2_gnu               conda-forge/linux-64     Cached
#   + bzip2                1.0.8  h7f98852_4          conda-forge/linux-64     Cached
#   + ca-certificates   2023.5.7  hbcca054_0          conda-forge/linux-64     Cached
#   + click                8.1.3  py39hf3d152e_1      conda-forge/linux-64     Cached
#   + ld_impl_linux-64      2.40  h41732ed_0          conda-forge/linux-64     Cached
#   + libffi               3.4.2  h7f98852_5          conda-forge/linux-64     Cached
#   + libgcc-ng           12.2.0  h65d4601_19         conda-forge/linux-64     Cached
#   + libgomp             12.2.0  h65d4601_19         conda-forge/linux-64     Cached
#   + libnsl               2.0.0  h7f98852_0          conda-forge/linux-64     Cached
#   + libsqlite           3.42.0  h2797004_0          conda-forge/linux-64     Cached
#   + libuuid             2.38.1  h0b41bf4_0          conda-forge/linux-64     Cached
#   + libzlib             1.2.13  h166bdaf_4          conda-forge/linux-64     Cached
#   + ncurses                6.3  h27087fc_1          conda-forge/linux-64     Cached
#   + openssl              3.1.0  hd590300_3          conda-forge/linux-64     Cached
#   + pip                 23.1.2  pyhd8ed1ab_0        conda-forge/noarch       Cached
#   + pystac               1.7.3  pyhd8ed1ab_0        conda-forge/noarch       Cached
#   + python              3.9.16  h2782a2a_0_cpython  conda-forge/linux-64     Cached
#   + python-dateutil      2.8.2  pyhd8ed1ab_0        conda-forge/noarch       Cached
#   + python_abi             3.9  3_cp39              conda-forge/linux-64     Cached
#   + readline               8.2  h8228510_1          conda-forge/linux-64     Cached
#   + setuptools          67.7.2  pyhd8ed1ab_0        conda-forge/noarch       Cached
#   + six                 1.16.0  pyh6c4a22f_0        conda-forge/noarch       Cached
#   + tk                  8.6.12  h27826a3_0          conda-forge/linux-64     Cached
#   + tzdata               2023c  h71feb2d_0          conda-forge/noarch       Cached
#   + wheel               0.40.0  pyhd8ed1ab_0        conda-forge/noarch       Cached
#   + xz                   5.2.6  h166bdaf_0          conda-forge/linux-64     Cached
#
#   Summary:
#
#   Install: 27 packages
#
#   Total download: 0 B
#
# ─────────────────────────────────────────────────────────────────────────────────────
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# To activate this environment, use
#
#      $ mamba activate /srv/conda/envs/env_stac
#
# To deactivate an active environment, use
#
#      $ mamba deactivate
#
# Collecting rio_stac
#   Using cached rio_stac-0.7.1-py3-none-any.whl (10 kB)
# Collecting rasterio (from rio_stac)
#   Using cached rasterio-1.3.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.1 MB)
# Requirement already satisfied: pystac<2.0.0,>=1.0.0 in /workspace/.conda_envs/env_stac/lib/python3.9/site-packages (from rio_stac) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in /workspace/.conda_envs/env_stac/lib/python3.9/site-packages (from pystac<2.0.0,>=1.0.0->rio_stac) (2.8.2)
# Collecting affine (from rasterio->rio_stac)
#   Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting attrs (from rasterio->rio_stac)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting certifi (from rasterio->rio_stac)
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Requirement already satisfied: click>=4.0 in /workspace/.conda_envs/env_stac/lib/python3.9/site-packages (from rasterio->rio_stac) (8.1.3)
# Collecting cligj>=0.5 (from rasterio->rio_stac)
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting numpy>=1.18 (from rasterio->rio_stac)
#   Using cached numpy-1.24.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting snuggs>=1.4.1 (from rasterio->rio_stac)
#   Using cached snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins (from rasterio->rio_stac)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /workspace/.conda_envs/env_stac/lib/python3.9/site-packages (from rasterio->rio_stac) (67.7.2)
# Requirement already satisfied: six>=1.5 in /workspace/.conda_envs/env_stac/lib/python3.9/site-packages (from python-dateutil>=2.7.0->pystac<2.0.0,>=1.0.0->rio_stac) (1.16.0)
# Collecting pyparsing>=2.1.6 (from snuggs>=1.4.1->rasterio->rio_stac)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Installing collected packages: pyparsing, numpy, cligj, click-plugins, certifi, attrs, affine, snuggs, rasterio, rio_stac
# Successfully installed affine-2.4.0 attrs-23.1.0 certifi-2023.5.7 click-plugins-1.1.1 cligj-0.7.2 numpy-1.24.3 pyparsing-3.0.9 rasterio-1.3.6 rio_stac-0.7.1 snuggs-1.4.7
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.23.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
# Remove all contents from the following package caches?
#   - /srv/conda/pkgs

# %% [markdown]
# ## Application Package inspection
#
# Open the `app-package.cwl` Application Package and familiarise yourself with its structure, to understand what's going on during execution:
#
# 1. Inspect the main workflow which `id` is **`water_bodies`**:
#     1.1. What are the input parameters? *(stac_items, aoi, epsg)*
#     1.2. What are the steps of this workflow? *(node_water_bodies, node_stac)*
# 2. Inspect the workflow which `id` is **`detect_water_body`**:
#     2.1. What are the steps of this workflow? *(node_crop, node_normalized_difference, node_otsu)*
# 3. Inspect each of the `CommandLineTool` of `id`: **`crop`**, **`norm_diff`**, **`otsu`** and **`stac`**
#     3.1. Inspect each of the `Dockerfile`

# %% [markdown]
# ## Application Package execution
#
# The water bodies Application Package can be executed with:
# ```
# cwltool --no-container app-package.cwl#water_bodies params.yml > out.json
# ```
# where:
# * `cwltool` is a Common Workflow Language runner.
# * The flag `--no-container` is used to instruct `cwltool` to use the local command-line tools instead of using the containers.
# * `app-package.cwl#water_bodies` defines the CWL file to execute as well as the entry point after the `#` symbol. Here it's the `Workflow` with the id `water_bodies`.
# * The file `params.yml` is used to define the input parameters. In this case, these are:
#
# ```
# stac_items:
# - "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A"
# - "https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A"
#
# aoi: "-121.399,39.834,-120.74,40.472"
# epsg: "EPSG:4326"
# ```
# * `out.json` is used to store the execution logs

# %%
# !cwltool --no-container ../water-bodies/app-package.cwl#water_bodies ../water-bodies/params.yml > out.json
# Out:
# INFO /srv/conda/bin/cwltool 3.1.20220224085855
# INFO Resolved '../water-bodies/app-package.cwl#water_bodies' to 'file:///workspace/workshop/07_app_package/water-bodies/app-package.cwl#water_bodies'
# INFO [workflow ] start
# INFO [workflow ] starting step node_water_bodies
# INFO [step node_water_bodies] start
# INFO [workflow node_water_bodies] start
# INFO [workflow node_water_bodies] starting step node_crop
# INFO [step node_crop] start
# INFO [job node_crop] /tmp/2k8ek72k$ python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     green \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A
# /srv/conda/envs/env_crop/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_crop] Max memory used: 68MiB
# INFO [job node_crop] completed success
# INFO [step node_crop] start
# INFO [job node_crop_2] /tmp/pqe0hkm0$ python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     nir \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A
# /srv/conda/envs/env_crop/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_crop_2] Max memory used: 68MiB
# INFO [job node_crop_2] completed success
# INFO [step node_crop] completed success
# INFO [workflow node_water_bodies] starting step node_normalized_difference
# INFO [step node_normalized_difference] start
# INFO [job node_normalized_difference] /tmp/n1u_mly7$ python \
#     -m \
#     app \
#     /tmp/kjb4uvfk/stg13f06661-48bc-4c66-ac33-5a62ab7dc269/crop_green.tif \
#     /tmp/kjb4uvfk/stg391feae6-dc86-4086-b39f-e3df3d6e04c0/crop_nir.tif
# /srv/conda/envs/env_norm_diff/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_normalized_difference] Max memory used: 1320MiB
# INFO [job node_normalized_difference] completed success
# INFO [step node_normalized_difference] completed success
# INFO [workflow node_water_bodies] starting step node_otsu
# INFO [step node_otsu] start
# INFO [job node_otsu] /tmp/lvqf3pvx$ python \
#     -m \
#     app \
#     /tmp/u0c7b5fe/stg186a0980-3933-4116-898a-cf43c8ba9bec/norm_diff.tif
# /srv/conda/envs/env_otsu/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_otsu] Max memory used: 394MiB
# INFO [job node_otsu] completed success
# INFO [step node_otsu] completed success
# INFO [workflow node_water_bodies] completed success
# INFO [step node_water_bodies] start
# INFO [workflow node_water_bodies_2] start
# INFO [workflow node_water_bodies_2] starting step node_crop_2
# INFO [step node_crop_2] start
# INFO [job node_crop_3] /tmp/ker3y34o$ python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     green \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A
# /srv/conda/envs/env_crop/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_crop_3] Max memory used: 68MiB
# INFO [job node_crop_3] completed success
# INFO [step node_crop_2] start
# INFO [job node_crop_4] /tmp/k2j9lwk9$ python \
#     -m \
#     app \
#     --aoi \
#     -121.399,39.834,-120.74,40.472 \
#     --band \
#     nir \
#     --epsg \
#     EPSG:4326 \
#     --input-item \
#     https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A
# /srv/conda/envs/env_crop/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_crop_4] Max memory used: 69MiB
# INFO [job node_crop_4] completed success
# INFO [step node_crop_2] completed success
# INFO [workflow node_water_bodies_2] starting step node_normalized_difference_2
# INFO [step node_normalized_difference_2] start
# INFO [job node_normalized_difference_2] /tmp/2paqihod$ python \
#     -m \
#     app \
#     /tmp/isdvrv1i/stg8dcf47f4-9ada-48ef-8c20-0d28c8353276/crop_green.tif \
#     /tmp/isdvrv1i/stgefa3db7e-d530-47ad-8e0c-819352b672ed/crop_nir.tif
# /srv/conda/envs/env_norm_diff/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_normalized_difference_2] Max memory used: 1320MiB
# INFO [job node_normalized_difference_2] completed success
# INFO [step node_normalized_difference_2] completed success
# INFO [workflow node_water_bodies_2] starting step node_otsu_2
# INFO [step node_otsu_2] start
# INFO [job node_otsu_2] /tmp/nr9vsfe5$ python \
#     -m \
#     app \
#     /tmp/xfivsth7/stgc1a3166b-cfe5-4038-8d7d-4f2b4358effc/norm_diff.tif
# /srv/conda/envs/env_otsu/lib/python3.11/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# INFO [job node_otsu_2] Max memory used: 410MiB
# INFO [job node_otsu_2] completed success
# INFO [step node_otsu_2] completed success
# INFO [workflow node_water_bodies_2] completed success
# INFO [step node_water_bodies] completed success
# INFO [workflow ] starting step node_stac
# INFO [step node_stac] start
# INFO [job node_stac] /tmp/gh0tk8w8$ python \
#     -m \
#     app \
#     --input-item \
#     https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_10TFK_20210713_0_L2A \
#     --water-body \
#     /tmp/9fkfl654/stg7e6a0562-7ad7-450c-8164-9434c3743c04/otsu.tif \
#     --input-item \
#     https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_10TFK_20220524_0_L2A \
#     --water-body \
#     /tmp/9fkfl654/stged3b9c5f-7ec2-4ab5-8610-29a5aec521e5/otsu.tif
# INFO [job node_stac] Max memory used: 73MiB
# INFO [job node_stac] completed success
# INFO [step node_stac] completed success
# INFO [workflow ] completed success
# INFO Final process status is success

# %% [markdown]
# ## Result inspection
#
# The execution of the `cwltool` generates the output `out.json` file, as well as a folder which name is a 8-character alphanumeric string. In this folder are stored the generated `catalog.json` and the `otsu.tif` and related STAC item for each of the two input Sentinel-2 images, in the structure below:
# * `catalog.json`
# * `S2A_10TFK_20220524_0_L2A`
#     * `otsu.tif`
#     * `S2A_10TFK_20220524_0_L2A.json`
# * `S2A_10TFK_20220524_0_L2A`
#     * `otsu.tif`
#     * `S2A_10TFK_20220524_0_L2A`

# %% [markdown]
# You can plot the output `otsu.tif` files with the `visualisation.ipynb` Jupyter Notebook. This Notebook uses `pystac` to access the geotiffs produced, `leafmap` to plot the tiles served by a local tile server. Open the Notebook and run all cells.
#
# First, run the commands below to create the environment:

# %%
# !mamba create -c conda-forge -y -p /srv/conda/envs/env_visual pystac ipykernel jupyterlab localtileserver jupyter-server-proxy pip && \
    /srv/conda/envs/env_visual/bin/pip install leafmap
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.23.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pystac', 'ipykernel', 'jupyterlab', 'localtileserver', 'jupyter-server-proxy', 'pip']
#
# [+] 0.0s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.1s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/linux-64   ━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# pkgs/main/linux-64   ╸━━━━━━━━━━━━━━━╸━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 0.3s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━ 300.2kB /  ??.?MB @   1.0MB/s  0.3s
# conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━ 337.8kB /  ??.?MB @   1.1MB/s  0.3s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━ 532.3kB /  ??.?MB @   1.8MB/s  0.3s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━ 491.2kB /  ??.?MB @   1.6MB/s  0.3s
# pkgs/main/linux-64   ━━━╸━━━━━━━━━━━━━━━╸━━━ 262.1kB /  ??.?MB @   1.0MB/s  0.3s[+] 0.4s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━ 862.4kB /  ??.?MB @   2.2MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━ 817.2kB /  ??.?MB @   2.0MB/s  0.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━ 981.9kB /  ??.?MB @   2.5MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━   1.0MB /  ??.?MB @   2.5MB/s  0.4s
# pkgs/main/linux-64   ━━━━━╸━━━━━━━━━━━━━━━╸━ 782.3kB /  ??.?MB @   2.2MB/s  0.4s[+] 0.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   1.3MB /  ??.?MB @   2.5MB/s  0.5s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   1.0MB /  ??.?MB @   2.3MB/s  0.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   1.2MB /  ??.?MB @   2.7MB/s  0.5s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   1.3MB /  ??.?MB @   2.9MB/s  0.5s
# pkgs/main/linux-64   ━━━━━━━╸━━━━━━━━━━━━━━━   1.3MB /  ??.?MB @   2.8MB/s  0.5s[+] 0.6s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━   1.5MB /  ??.?MB @   2.7MB/s  0.6s
# conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━   1.5MB /  ??.?MB @   2.7MB/s  0.6s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━   1.7MB /  ??.?MB @   3.1MB/s  0.6s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   1.9MB /  ??.?MB @   3.4MB/s  0.6s
# pkgs/main/linux-64   ━━━━━━━━━╸━━━━━━━━━━━━━   1.7MB /  ??.?MB @   3.1MB/s  0.6s[+] 0.7s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   2.0MB /  ??.?MB @   3.0MB/s  0.7s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   2.0MB /  ??.?MB @   3.0MB/s  0.7s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━   2.2MB /  ??.?MB @   3.5MB/s  0.7s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   2.4MB /  ??.?MB @   3.7MB/s  0.7s
# pkgs/main/linux-64   ━━━━━━━━━━━╸━━━━━━━━━━━   2.3MB /  ??.?MB @   3.5MB/s  0.7s[+] 0.8s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   2.5MB /  ??.?MB @   3.3MB/s  0.8s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   2.4MB /  ??.?MB @   3.2MB/s  0.8s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━   2.8MB /  ??.?MB @   3.7MB/s  0.8s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   2.9MB /  ??.?MB @   3.8MB/s  0.8s
# pkgs/main/linux-64   ━━━━━━━━╸━━━━━━━━━━━━━━   2.8MB /  ??.?MB @   3.7MB/s  0.8s[+] 0.9s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━   2.9MB /  ??.?MB @   3.4MB/s  0.9s
# conda-forge/noarch   ━━━╸━━━━━━━━━━━━━━━╸━━━   2.8MB /  ??.?MB @   3.3MB/s  0.9s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   3.3MB /  ??.?MB @   3.8MB/s  0.9s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   3.4MB /  ??.?MB @   4.0MB/s  0.9s
# pkgs/main/linux-64   ━━━━━━━━━━╸━━━━━━━━━━━━   3.2MB /  ??.?MB @   3.8MB/s  0.9s[+] 1.0s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   3.4MB /  ??.?MB @   3.5MB/s  1.0s
# conda-forge/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━   3.3MB /  ??.?MB @   3.5MB/s  1.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   3.8MB /  ??.?MB @   4.0MB/s  1.0s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━   3.9MB /  ??.?MB @   4.1MB/s  1.0s
# pkgs/main/linux-64   ━━━━━━━━━━━━╸━━━━━━━━━━   3.8MB /  ??.?MB @   3.9MB/s  1.0s[+] 1.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   3.7MB /  ??.?MB @   3.5MB/s  1.1s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   3.8MB /  ??.?MB @   3.6MB/s  1.1s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   4.3MB /  ??.?MB @   4.1MB/s  1.1s
# conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━   4.4MB /  ??.?MB @   4.2MB/s  1.1s
# pkgs/main/linux-64   ━━━━━━━━━━━━━━╸━━━━━━━━   4.3MB /  ??.?MB @   4.1MB/s  1.1s[+] 1.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   4.2MB /  ??.?MB @   3.7MB/s  1.2s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   4.3MB /  ??.?MB @   3.7MB/s  1.2s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   4.9MB /  ??.?MB @   4.2MB/s  1.2s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   4.9MB /  ??.?MB @   4.3MB/s  1.2s
# pkgs/main/linux-64   ╸━━━━━━━━━━━━━━━╸━━━━━━   4.8MB /  ??.?MB @   4.1MB/s  1.2s[+] 1.3s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   4.7MB /  ??.?MB @   3.8MB/s  1.3s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   4.7MB /  ??.?MB @   3.8MB/s  1.3s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━   5.3MB /  ??.?MB @   4.2MB/s  1.3s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   5.3MB /  ??.?MB @   4.3MB/s  1.3s
# pkgs/main/linux-64   ━━━╸━━━━━━━━━━━━━━━╸━━━   5.3MB /  ??.?MB @   4.2MB/s  1.3s[+] 1.4s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━   4.9MB /  ??.?MB @   3.8MB/s  1.4s
# conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━   5.0MB /  ??.?MB @   3.8MB/s  1.4s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   5.6MB /  ??.?MB @   4.3MB/s  1.4s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   5.6MB /  ??.?MB @   4.3MB/s  1.4s
# pkgs/main/linux-64   ━━━━╸━━━━━━━━━━━━━━━╸━━   5.6MB /  ??.?MB @   4.2MB/s  1.4s
# eoepca/linux-64      ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 1.5s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━   4.9MB /  ??.?MB @   3.8MB/s  1.5s
# conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━   5.0MB /  ??.?MB @   3.8MB/s  1.5s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   5.6MB /  ??.?MB @   4.3MB/s  1.5s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   5.6MB /  ??.?MB @   4.3MB/s  1.5s
# eoepca/linux-64      ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2spkgs/main/linux-64                                   5.7MB @   4.3MB/s  1.5s
# [+] 1.6s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   5.1MB /  ??.?MB @   3.3MB/s  1.6s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   5.2MB /  ??.?MB @   3.3MB/s  1.6s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   5.8MB /  ??.?MB @   3.7MB/s  1.6s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   5.7MB /  ??.?MB @   3.7MB/s  1.6s
# eoepca/linux-64      ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s[+] 1.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   6.0MB /  ??.?MB @   3.6MB/s  1.7s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━   5.8MB /  ??.?MB @   3.5MB/s  1.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   6.5MB /  ??.?MB @   3.9MB/s  1.7s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   6.6MB /  ??.?MB @   4.0MB/s  1.7s
# eoepca/linux-64      ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4s[+] 1.8s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━   6.6MB /  ??.?MB @   3.8MB/s  1.8s
# conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━   6.9MB /  ??.?MB @   3.9MB/s  1.8s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━   7.5MB /  ??.?MB @   4.3MB/s  1.8s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   7.3MB /  ??.?MB @   4.2MB/s  1.8s
# eoepca/linux-64      ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.5s[+] 1.9s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   7.1MB /  ??.?MB @   3.8MB/s  1.9s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   7.3MB /  ??.?MB @   4.0MB/s  1.9s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━   8.0MB /  ??.?MB @   4.3MB/s  1.9s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   7.7MB /  ??.?MB @   4.1MB/s  1.9s
# eoepca/linux-64      ━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.6s[+] 2.0s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━   7.6MB /  ??.?MB @   3.9MB/s  2.0s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   7.7MB /  ??.?MB @   4.0MB/s  2.0s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━   8.3MB /  ??.?MB @   4.2MB/s  2.0s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━   8.2MB /  ??.?MB @   4.2MB/s  2.0s
# eoepca/linux-64      ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.7seoepca/linux-64                                               No change
# pkgs/main/noarch                                              No change
# [+] 2.1s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━   8.1MB /  ??.?MB @   3.9MB/s  2.1s
# conda-forge/noarch   ━━━╸━━━━━━━━━━━━━━━╸━━━   8.1MB /  ??.?MB @   4.0MB/s  2.1s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━   8.6MB /  ??.?MB @   4.2MB/s  2.1s
# conda-forge/noarch   ╸━━━━━━━━━━━━━━━╸━━━━━━   8.6MB /  ??.?MB @   4.2MB/s  2.1s
# terradue/noarch      ━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 2.2s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━   8.7MB /  ??.?MB @   4.0MB/s  2.2s
# conda-forge/noarch   ━━━━━╸━━━━━━━━━━━━━━━╸━   8.6MB /  ??.?MB @   4.0MB/s  2.2s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━   9.2MB /  ??.?MB @   4.2MB/s  2.2s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━   9.1MB /  ??.?MB @   4.2MB/s  2.2s
# terradue/noarch      ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 2.3s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   9.2MB /  ??.?MB @   4.1MB/s  2.3s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   9.1MB /  ??.?MB @   4.0MB/s  2.3s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━   9.7MB /  ??.?MB @   4.3MB/s  2.3s
# conda-forge/noarch   ━━━━╸━━━━━━━━━━━━━━━╸━━   9.5MB /  ??.?MB @   4.2MB/s  2.3s
# terradue/noarch      ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 2.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   9.8MB /  ??.?MB @   4.1MB/s  2.4s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━   9.5MB /  ??.?MB @   4.0MB/s  2.4s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  10.2MB /  ??.?MB @   4.3MB/s  2.4s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━  10.0MB /  ??.?MB @   4.2MB/s  2.4s
# terradue/noarch      ━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s[+] 2.5s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  10.3MB /  ??.?MB @   4.2MB/s  2.5s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━  10.0MB /  ??.?MB @   4.1MB/s  2.5s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  10.7MB /  ??.?MB @   4.4MB/s  2.5s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━  10.5MB /  ??.?MB @   4.3MB/s  2.5s
# terradue/noarch      ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4sterradue/noarch                                               No change
# pkgs/r/linux-64                                               No change
# [+] 2.6s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  10.8MB /  ??.?MB @   4.2MB/s  2.6s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━  10.3MB /  ??.?MB @   4.0MB/s  2.6s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  11.2MB /  ??.?MB @   4.4MB/s  2.6s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━  11.0MB /  ??.?MB @   4.3MB/s  2.6s
# r/linux-64           ━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0sr/linux-64                                                    No change
# [+] 2.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  11.4MB /  ??.?MB @   4.3MB/s  2.7s
# conda-forge/noarch   ━━━━━━━━━━╸━━━━━━━━━━━━  10.8MB /  ??.?MB @   4.1MB/s  2.7s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  11.8MB /  ??.?MB @   4.4MB/s  2.7s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━  11.4MB /  ??.?MB @   4.3MB/s  2.7s
# eoepca/noarch        ━━━━━━━━━━╸━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 2.8s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━  12.0MB /  ??.?MB @   4.3MB/s  2.8s
# conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━  11.2MB /  ??.?MB @   4.1MB/s  2.8s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  12.2MB /  ??.?MB @   4.4MB/s  2.8s
# conda-forge/noarch   ━━━━━━━━━╸━━━━━━━━━━━━━  11.8MB /  ??.?MB @   4.3MB/s  2.8s
# eoepca/noarch        ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 2.9s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  12.5MB /  ??.?MB @   4.4MB/s  2.9s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━  11.5MB /  ??.?MB @   4.0MB/s  2.9s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  12.7MB /  ??.?MB @   4.5MB/s  2.9s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━  12.3MB /  ??.?MB @   4.3MB/s  2.9s
# terradue/linux-64    ━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# eoepca/noarch        ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s[+] 3.0s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━  12.5MB @   4.4MB/s             3.0s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━  11.5MB @   4.0MB/s             3.0s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━  12.7MB @   4.5MB/s             3.0s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━  12.3MB @   4.3MB/s Finalizing  3.0s
# terradue/linux-64    ━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B @  ??.?MB/s             0.1s
# eoepca/noarch        ━━━━━━━━╸━━━━━━━━━━━━━   0.0 B @  ??.?MB/s             0.3s[+] 3.1s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  12.5MB /  ??.?MB @   4.4MB/s  3.1s
# conda-forge/noarch   ━━━━━━━━━━━━━━╸━━━━━━━━  11.5MB /  ??.?MB @   4.0MB/s  3.1s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  12.7MB /  ??.?MB @   4.5MB/s  3.1s
# terradue/linux-64    ━━━━━╸━━━━━━━━━━━━━━━╸━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# eoepca/noarch        ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.4sconda-forge/noarch                                 @   4.3MB/s  3.1s
# eoepca/noarch                                                 No change
# [+] 3.2s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  12.5MB /  ??.?MB @   3.9MB/s  3.2s
# conda-forge/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━  11.6MB /  ??.?MB @   3.6MB/s  3.2s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━  12.8MB /  ??.?MB @   4.0MB/s  3.2s
# terradue/linux-64    ━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.3s
# r/noarch             ━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0sr/noarch                                                      No change
# pkgs/r/noarch                                                 No change
# terradue/linux-64                                             No change
# [+] 3.3s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━  13.4MB /  ??.?MB @   4.1MB/s  3.3s
# conda-forge/noarch   ━━╸━━━━━━━━━━━━━━━╸━━━━  12.2MB /  ??.?MB @   3.7MB/s  3.3s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  14.0MB /  ??.?MB @   4.3MB/s  3.3s[+] 3.4s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━━  14.4MB @   4.3MB/s             3.4s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━  12.3MB @   3.7MB/s Downloaded  3.4s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━  14.3MB @   4.3MB/s             3.4s[+] 3.5s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━━  14.4MB @   4.3MB/s             3.5s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━  12.3MB @   3.7MB/s Finalizing  3.5s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━  14.3MB @   4.3MB/s             3.5s[+] 3.6s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  14.4MB /  ??.?MB @   4.3MB/s  3.6s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━  14.3MB /  ??.?MB @   4.3MB/s  3.6sconda-forge/noarch                                 @   3.7MB/s  3.5s
# [+] 3.7s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  15.2MB /  ??.?MB @   4.1MB/s  3.7s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  15.0MB /  ??.?MB @   4.1MB/s  3.7s[+] 3.8s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  16.5MB /  ??.?MB @   4.4MB/s  3.8s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  15.2MB /  ??.?MB @   4.0MB/s  3.8s[+] 3.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  17.0MB /  ??.?MB @   4.4MB/s  3.9s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  15.9MB /  ??.?MB @   4.1MB/s  3.9s[+] 4.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  17.5MB /  ??.?MB @   4.4MB/s  4.0s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  16.4MB /  ??.?MB @   4.1MB/s  4.0s[+] 4.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  18.0MB /  ??.?MB @   4.4MB/s  4.1s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  16.9MB /  ??.?MB @   4.1MB/s  4.1s[+] 4.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  18.6MB /  ??.?MB @   4.4MB/s  4.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  17.4MB /  ??.?MB @   4.2MB/s  4.2s[+] 4.3s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━  19.1MB /  ??.?MB @   4.5MB/s  4.3s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  17.9MB /  ??.?MB @   4.2MB/s  4.3s[+] 4.4s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  19.7MB /  ??.?MB @   4.5MB/s  4.4s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  18.5MB /  ??.?MB @   4.2MB/s  4.4s[+] 4.5s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━  20.1MB /  ??.?MB @   4.5MB/s  4.5s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━  19.0MB /  ??.?MB @   4.2MB/s  4.5s[+] 4.6s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  20.6MB /  ??.?MB @   4.5MB/s  4.6s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━  19.1MB /  ??.?MB @   4.2MB/s  4.6s[+] 4.7s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  21.1MB /  ??.?MB @   4.5MB/s  4.7s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  19.7MB /  ??.?MB @   4.2MB/s  4.7s[+] 4.8s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  21.6MB /  ??.?MB @   4.5MB/s  4.8s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  20.2MB /  ??.?MB @   4.2MB/s  4.8s[+] 4.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  22.1MB /  ??.?MB @   4.5MB/s  4.9s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  20.7MB /  ??.?MB @   4.2MB/s  4.9s[+] 5.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  22.6MB /  ??.?MB @   4.5MB/s  5.0s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  21.1MB /  ??.?MB @   4.2MB/s  5.0s[+] 5.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  23.0MB /  ??.?MB @   4.5MB/s  5.1s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  21.6MB /  ??.?MB @   4.3MB/s  5.1s[+] 5.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  23.6MB /  ??.?MB @   4.5MB/s  5.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  22.1MB /  ??.?MB @   4.3MB/s  5.2s[+] 5.3s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━  24.1MB /  ??.?MB @   4.6MB/s  5.3s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  22.7MB /  ??.?MB @   4.3MB/s  5.3s[+] 5.4s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  24.6MB /  ??.?MB @   4.6MB/s  5.4s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  23.2MB /  ??.?MB @   4.3MB/s  5.4s[+] 5.5s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━  25.2MB /  ??.?MB @   4.6MB/s  5.5s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━  23.7MB /  ??.?MB @   4.3MB/s  5.5s[+] 5.6s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  25.7MB /  ??.?MB @   4.6MB/s  5.6s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━  24.2MB /  ??.?MB @   4.3MB/s  5.6s[+] 5.7s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  26.2MB /  ??.?MB @   4.6MB/s  5.7s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  24.7MB /  ??.?MB @   4.3MB/s  5.7s[+] 5.8s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  26.7MB /  ??.?MB @   4.6MB/s  5.8s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  25.2MB /  ??.?MB @   4.4MB/s  5.8s[+] 5.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  27.3MB /  ??.?MB @   4.6MB/s  5.9s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  25.8MB /  ??.?MB @   4.4MB/s  5.9s[+] 6.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  27.8MB /  ??.?MB @   4.6MB/s  6.0s
# conda-forge/linux-64 ━━━━━━━━━━╸━━━━━━━━━━━━  26.3MB /  ??.?MB @   4.4MB/s  6.0s[+] 6.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  28.2MB /  ??.?MB @   4.6MB/s  6.1s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  26.9MB /  ??.?MB @   4.4MB/s  6.1s[+] 6.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  28.6MB /  ??.?MB @   4.6MB/s  6.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━  27.3MB /  ??.?MB @   4.4MB/s  6.2s[+] 6.3s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━╸━━━━━━  29.0MB /  ??.?MB @   4.6MB/s  6.3s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━  27.9MB /  ??.?MB @   4.4MB/s  6.3s[+] 6.4s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━  29.4MB /  ??.?MB @   4.6MB/s  6.4s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━  28.4MB /  ??.?MB @   4.4MB/s  6.4s[+] 6.5s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━╸━━  29.8MB /  ??.?MB @   4.6MB/s  6.5s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━╸━  28.8MB /  ??.?MB @   4.4MB/s  6.5s[+] 6.6s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  30.2MB /  ??.?MB @   4.6MB/s  6.6s
# conda-forge/linux-64 ━━━━━━━╸━━━━━━━━━━━━━━━  29.3MB /  ??.?MB @   4.4MB/s  6.6s[+] 6.7s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.7MB /  ??.?MB @   4.6MB/s  6.7s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  29.7MB /  ??.?MB @   4.4MB/s  6.7s[+] 6.8s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  31.1MB /  ??.?MB @   4.6MB/s  6.8s
# conda-forge/linux-64 ━━━━━━━━━━━━╸━━━━━━━━━━  30.2MB /  ??.?MB @   4.4MB/s  6.8s[+] 6.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  31.6MB /  ??.?MB @   4.6MB/s  6.9s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  6.9s[+] 7.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  31.6MB /  ??.?MB @   4.6MB/s  7.0s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.0s[+] 7.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  31.6MB /  ??.?MB @   4.6MB/s  7.1s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.1s[+] 7.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  31.6MB /  ??.?MB @   4.6MB/s  7.2s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.2s[+] 7.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  31.6MB @   4.6MB/s Finalizing  7.3s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━  30.6MB @   4.4MB/s             7.3s[+] 7.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  31.6MB @   4.6MB/s Finalizing  7.4s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━  30.6MB @   4.4MB/s             7.4s[+] 7.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  31.6MB @   4.6MB/s Finalizing  7.5s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━  30.6MB @   4.4MB/s             7.5s[+] 7.6s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.6s[+] 7.7s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.7s[+] 7.8s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.8s[+] 7.9s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  30.6MB /  ??.?MB @   4.4MB/s  7.9sconda-forge/linux-64                               @   4.6MB/s  7.6s
# [+] 8.0s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  30.7MB /  ??.?MB @   3.9MB/s  8.0s[+] 8.1s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  30.7MB /  ??.?MB @   3.9MB/s  8.1s[+] 8.2s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  30.7MB /  ??.?MB @   3.9MB/s  8.2s[+] 8.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  31.6MB @   4.0MB/s Finalizing  8.3s[+] 8.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  31.6MB @   4.0MB/s Finalizing  8.4s[+] 8.5s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  31.6MB @   4.0MB/s Finalizing  8.5s[+] 8.6s
# [+] 8.7s
# [+] 8.8s
# [+] 8.9s
# conda-forge/linux-64                               @   4.0MB/s  8.6s
# Transaction
#
#   Prefix: /srv/conda/envs/env_visual
#
#   Updating specs:
#
#    - pystac
#    - ipykernel
#    - jupyterlab
#    - localtileserver
#    - jupyter-server-proxy
#    - pip
#
#
#   Package                               Version  Build                Channel                    Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                           0.1  conda_forge          conda-forge/linux-64     Cached
#   + _openmp_mutex                           4.5  2_gnu                conda-forge/linux-64     Cached
#   + aiohttp                               3.8.4  py310h1fa729e_0      conda-forge/linux-64     Cached
#   + aiosignal                             1.3.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + aniso8601                             9.0.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + anyio                                 3.6.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + argon2-cffi                          21.3.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + argon2-cffi-bindings                 21.2.0  py310h5764c6d_3      conda-forge/linux-64     Cached
#   + asttokens                             2.2.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + async-lru                             2.0.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + async-timeout                         4.0.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + attrs                                23.1.0  pyh71513ae_1         conda-forge/noarch       Cached
#   + babel                                2.12.1  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + backcall                              0.2.0  pyh9f0ad1d_0         conda-forge/noarch       Cached
#   + backports                               1.0  pyhd8ed1ab_3         conda-forge/noarch       Cached
#   + backports.functools_lru_cache         1.6.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + beautifulsoup4                       4.12.2  pyha770c72_0         conda-forge/noarch       Cached
#   + bleach                                6.0.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + blosc                                1.21.4  h0f2a231_0           conda-forge/linux-64     Cached
#   + boost-cpp                            1.78.0  h6582d0a_3           conda-forge/linux-64     Cached
#   + brotli                                1.0.9  h166bdaf_8           conda-forge/linux-64     Cached
#   + brotli-bin                            1.0.9  h166bdaf_8           conda-forge/linux-64     Cached
#   + bzip2                                 1.0.8  h7f98852_4           conda-forge/linux-64     Cached
#   + c-ares                               1.19.1  hd590300_0           conda-forge/linux-64     Cached
#   + ca-certificates                    2023.5.7  hbcca054_0           conda-forge/linux-64     Cached
#   + cachetools                            5.3.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + cairo                                1.16.0  hbbf8b49_1016        conda-forge/linux-64     Cached
#   + certifi                            2023.5.7  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + cffi                                 1.15.1  py310h255011f_3      conda-forge/linux-64     Cached
#   + cfitsio                               4.2.0  hd9d235c_0           conda-forge/linux-64     Cached
#   + charset-normalizer                    2.1.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + click                                 8.1.3  py310hff52083_1      conda-forge/linux-64     Cached
#   + curl                                  8.1.1  h409715c_0           conda-forge/linux-64       90kB
#   + debugpy                               1.6.7  py310heca2aa9_0      conda-forge/linux-64     Cached
#   + decorator                             5.1.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + defusedxml                            0.7.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + entrypoints                             0.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + executing                             1.2.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + expat                                 2.5.0  hcb278e6_1           conda-forge/linux-64     Cached
#   + flask                                 2.1.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + flask-caching                        1.10.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + flask-cors                           3.0.10  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + flask-restx                           1.0.6  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + flit-core                             3.9.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + font-ttf-dejavu-sans-mono              2.37  hab24e00_0           conda-forge/noarch       Cached
#   + font-ttf-inconsolata                  3.000  h77eed37_0           conda-forge/noarch       Cached
#   + font-ttf-source-code-pro              2.038  h77eed37_0           conda-forge/noarch       Cached
#   + font-ttf-ubuntu                        0.83  hab24e00_0           conda-forge/noarch       Cached
#   + fontconfig                           2.14.2  h14ed4e7_0           conda-forge/linux-64     Cached
#   + fonts-conda-ecosystem                     1  0                    conda-forge/noarch       Cached
#   + fonts-conda-forge                         1  0                    conda-forge/noarch       Cached
#   + freetype                             2.12.1  hca18f0e_1           conda-forge/linux-64     Cached
#   + freexl                                1.0.6  h166bdaf_1           conda-forge/linux-64     Cached
#   + frozenlist                            1.3.3  py310h5764c6d_0      conda-forge/linux-64     Cached
#   + gdal                                  3.7.0  py310h52aca19_1      conda-forge/linux-64     Cached
#   + geos                                 3.11.2  hcb278e6_0           conda-forge/linux-64     Cached
#   + geotiff                               1.7.1  h480ec47_8           conda-forge/linux-64     Cached
#   + gettext                              0.21.1  h27087fc_0           conda-forge/linux-64     Cached
#   + giflib                                5.2.1  h0b41bf4_3           conda-forge/linux-64     Cached
#   + h11                                  0.14.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + hdf4                                 4.2.15  h501b40f_6           conda-forge/linux-64     Cached
#   + hdf5                                 1.14.0  nompi_hb72d44e_103   conda-forge/linux-64     Cached
#   + icu                                    72.1  hcb278e6_0           conda-forge/linux-64     Cached
#   + idna                                    3.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + importlib-metadata                    6.6.0  pyha770c72_0         conda-forge/noarch       Cached
#   + importlib_metadata                    6.6.0  hd8ed1ab_0           conda-forge/noarch       Cached
#   + importlib_resources                  5.12.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + ipykernel                            6.14.0  py310hfdc917e_0      conda-forge/linux-64     Cached
#   + ipython                               8.4.0  py310hff52083_0      conda-forge/linux-64     Cached
#   + itsdangerous                          2.1.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jedi                                 0.18.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jinja2                                3.1.2  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + json-c                                 0.16  hc379101_0           conda-forge/linux-64     Cached
#   + json5                                 0.9.5  pyh9f0ad1d_0         conda-forge/noarch       Cached
#   + jsonschema                           4.17.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyter-lsp                           2.1.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyter-server-proxy                  4.0.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyter_client                        8.2.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyter_core                          5.3.0  py310hff52083_0      conda-forge/linux-64     Cached
#   + jupyter_events                        0.6.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyter_server                        2.5.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyter_server_terminals              0.4.4  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + jupyterlab                            4.0.0  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + jupyterlab_pygments                   0.2.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + jupyterlab_server                    2.22.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + kealib                                1.5.1  h3845be2_3           conda-forge/linux-64     Cached
#   + keyutils                              1.6.1  h166bdaf_0           conda-forge/linux-64     Cached
#   + krb5                                 1.20.1  h81ceb04_0           conda-forge/linux-64     Cached
#   + large-image                          1.20.6  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + large-image-source-gdal              1.20.6  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + lcms2                                  2.15  haa2dc70_1           conda-forge/linux-64     Cached
#   + ld_impl_linux-64                       2.40  h41732ed_0           conda-forge/linux-64     Cached
#   + lerc                                  4.0.0  h27087fc_0           conda-forge/linux-64     Cached
#   + libaec                                1.0.6  hcb278e6_1           conda-forge/linux-64     Cached
#   + libarchive                            3.6.2  h039dbb9_1           conda-forge/linux-64     Cached
#   + libblas                               3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libbrotlicommon                       1.0.9  h166bdaf_8           conda-forge/linux-64     Cached
#   + libbrotlidec                          1.0.9  h166bdaf_8           conda-forge/linux-64     Cached
#   + libbrotlienc                          1.0.9  h166bdaf_8           conda-forge/linux-64     Cached
#   + libcblas                              3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libcurl                               8.1.1  h409715c_0           conda-forge/linux-64      372kB
#   + libdeflate                             1.18  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libedit                        3.1.20191231  he28a2e2_2           conda-forge/linux-64     Cached
#   + libev                                  4.33  h516909a_1           conda-forge/linux-64     Cached
#   + libexpat                              2.5.0  hcb278e6_1           conda-forge/linux-64     Cached
#   + libffi                                3.4.2  h7f98852_5           conda-forge/linux-64     Cached
#   + libgcc-ng                            12.2.0  h65d4601_19          conda-forge/linux-64     Cached
#   + libgdal                               3.7.0  h9f4e061_1           conda-forge/linux-64     Cached
#   + libgfortran-ng                       12.2.0  h69a702a_19          conda-forge/linux-64     Cached
#   + libgfortran5                         12.2.0  h337968e_19          conda-forge/linux-64     Cached
#   + libglib                              2.76.3  hebfc3b9_0           conda-forge/linux-64        3MB
#   + libgomp                              12.2.0  h65d4601_19          conda-forge/linux-64     Cached
#   + libiconv                               1.17  h166bdaf_0           conda-forge/linux-64     Cached
#   + libjpeg-turbo                       2.1.5.1  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libkml                                1.3.0  h37653c0_1015        conda-forge/linux-64     Cached
#   + liblapack                             3.9.0  16_linux64_openblas  conda-forge/linux-64     Cached
#   + libnetcdf                             4.9.2  nompi_h0f3d0bb_105   conda-forge/linux-64     Cached
#   + libnghttp2                           1.52.0  h61bc06f_0           conda-forge/linux-64     Cached
#   + libnsl                                2.0.0  h7f98852_0           conda-forge/linux-64     Cached
#   + libopenblas                          0.3.21  pthreads_h78a6416_3  conda-forge/linux-64     Cached
#   + libpng                               1.6.39  h753d276_0           conda-forge/linux-64     Cached
#   + libpq                                  15.3  hbcd7760_1           conda-forge/linux-64     Cached
#   + librttopo                             1.1.0  h0d5128d_13          conda-forge/linux-64     Cached
#   + libsodium                            1.0.18  h36c2ea0_1           conda-forge/linux-64     Cached
#   + libspatialite                         5.0.1  hb46c372_26          conda-forge/linux-64     Cached
#   + libsqlite                            3.42.0  h2797004_0           conda-forge/linux-64     Cached
#   + libssh2                              1.10.0  hf14f497_3           conda-forge/linux-64     Cached
#   + libstdcxx-ng                         12.2.0  h46fd767_19          conda-forge/linux-64     Cached
#   + libtiff                               4.5.0  ha587672_6           conda-forge/linux-64     Cached
#   + libuuid                              2.38.1  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libwebp-base                          1.3.0  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libxcb                                 1.15  h0b41bf4_0           conda-forge/linux-64     Cached
#   + libxml2                              2.11.4  h0d562d8_0           conda-forge/linux-64     Cached
#   + libzip                                1.9.2  hc929e4a_1           conda-forge/linux-64     Cached
#   + libzlib                              1.2.13  h166bdaf_4           conda-forge/linux-64     Cached
#   + localtileserver                       0.6.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + lz4-c                                 1.9.4  hcb278e6_0           conda-forge/linux-64     Cached
#   + lzo                                    2.10  h516909a_1000        conda-forge/linux-64     Cached
#   + markupsafe                            2.1.2  py310h1fa729e_0      conda-forge/linux-64     Cached
#   + matplotlib-inline                     0.1.6  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + mistune                               2.0.5  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + multidict                             6.0.4  py310h1fa729e_0      conda-forge/linux-64     Cached
#   + nbclient                              0.8.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + nbconvert-core                        7.4.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + nbformat                              5.8.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + ncurses                                 6.3  h27087fc_1           conda-forge/linux-64     Cached
#   + nest-asyncio                          1.5.6  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + notebook-shim                         0.2.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + nspr                                   4.35  h27087fc_0           conda-forge/linux-64     Cached
#   + nss                                    3.89  he45b914_0           conda-forge/linux-64     Cached
#   + numpy                                1.24.3  py310ha4c1d20_0      conda-forge/linux-64     Cached
#   + openjpeg                              2.5.0  hfec8fc6_2           conda-forge/linux-64     Cached
#   + openssl                               3.1.0  hd590300_3           conda-forge/linux-64     Cached
#   + packaging                              23.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + palettable                            3.3.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pandocfilters                         1.5.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + parso                                 0.8.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pcre2                                 10.40  hc3806b6_0           conda-forge/linux-64     Cached
#   + pexpect                               4.8.0  pyh1a96a4e_2         conda-forge/noarch       Cached
#   + pickleshare                           0.7.5  py_1003              conda-forge/noarch       Cached
#   + pillow                                9.5.0  py310h582fbeb_1      conda-forge/linux-64     Cached
#   + pip                                  23.1.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pixman                               0.40.0  h36c2ea0_0           conda-forge/linux-64     Cached
#   + pkgutil-resolve-name                 1.3.10  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + platformdirs                          3.5.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + poppler                             23.05.0  hd18248d_1           conda-forge/linux-64     Cached
#   + poppler-data                         0.4.12  hd8ed1ab_0           conda-forge/noarch       Cached
#   + postgresql                             15.3  hd458b1d_1           conda-forge/linux-64     Cached
#   + proj                                  9.2.0  h8ffa02c_0           conda-forge/linux-64     Cached
#   + prometheus_client                    0.16.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + prompt-toolkit                       3.0.38  pyha770c72_0         conda-forge/noarch       Cached
#   + psutil                                5.9.5  py310h1fa729e_0      conda-forge/linux-64     Cached
#   + pthread-stubs                           0.4  h36c2ea0_1001        conda-forge/linux-64     Cached
#   + ptyprocess                            0.7.0  pyhd3deb0d_0         conda-forge/noarch       Cached
#   + pure_eval                             0.2.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pycparser                              2.21  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pygments                             2.15.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pyproj                                3.5.0  py310hb814896_1      conda-forge/linux-64     Cached
#   + pyrsistent                           0.19.3  py310h1fa729e_0      conda-forge/linux-64     Cached
#   + pysocks                               1.7.1  py310hff52083_5      conda-forge/linux-64     Cached
#   + pystac                                1.7.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python                              3.10.11  he550d4f_0_cpython   conda-forge/linux-64     Cached
#   + python-dateutil                       2.8.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python-fastjsonschema                2.17.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python-json-logger                    2.0.7  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + python_abi                             3.10  3_cp310              conda-forge/linux-64     Cached
#   + pytz                                 2023.3  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + pyyaml                                  6.0  py310h5764c6d_5      conda-forge/linux-64     Cached
#   + pyzmq                                25.0.2  py310h059b190_0      conda-forge/linux-64     Cached
#   + readline                                8.2  h8228510_1           conda-forge/linux-64     Cached
#   + requests                             2.31.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + rfc3339-validator                     0.1.4  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + rfc3986-validator                     0.1.1  pyh9f0ad1d_0         conda-forge/noarch       Cached
#   + scooby                                0.7.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + send2trash                            1.8.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + server-thread                         0.2.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + setuptools                           67.7.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + simpervisor                           1.0.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + six                                  1.16.0  pyh6c4a22f_0         conda-forge/noarch       Cached
#   + snappy                               1.1.10  h9fff704_0           conda-forge/linux-64     Cached
#   + sniffio                               1.3.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + soupsieve                       2.3.2.post1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + sqlite                               3.42.0  h2c6b66d_0           conda-forge/linux-64     Cached
#   + stack_data                            0.6.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + terminado                            0.15.0  py310hff52083_0      conda-forge/linux-64     Cached
#   + tiledb                               2.13.2  hd532e3d_0           conda-forge/linux-64     Cached
#   + tinycss2                              1.2.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + tk                                   8.6.12  h27826a3_0           conda-forge/linux-64     Cached
#   + tomli                                 2.0.1  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + tornado                               6.3.2  py310h2372a71_0      conda-forge/linux-64     Cached
#   + traitlets                             5.9.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + typing-extensions                     4.6.0  hd8ed1ab_0           conda-forge/noarch         10kB
#   + typing_extensions                     4.6.0  pyha770c72_0         conda-forge/noarch         34kB
#   + tzcode                                2023c  h0b41bf4_0           conda-forge/linux-64     Cached
#   + tzdata                                2023c  h71feb2d_0           conda-forge/noarch       Cached
#   + urllib3                               2.0.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + uvicorn                              0.22.0  py310hff52083_0      conda-forge/linux-64     Cached
#   + wcwidth                               0.2.6  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + webencodings                          0.5.1  py_1                 conda-forge/noarch       Cached
#   + websocket-client                      1.5.2  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + werkzeug                              2.1.2  pyhd8ed1ab_1         conda-forge/noarch       Cached
#   + wheel                                0.40.0  pyhd8ed1ab_0         conda-forge/noarch       Cached
#   + xerces-c                              3.2.4  h8d71039_2           conda-forge/linux-64     Cached
#   + xorg-kbproto                          1.0.7  h7f98852_1002        conda-forge/linux-64     Cached
#   + xorg-libice                          1.0.10  h7f98852_0           conda-forge/linux-64     Cached
#   + xorg-libsm                            1.2.3  hd9c2040_1000        conda-forge/linux-64     Cached
#   + xorg-libx11                           1.8.4  h8ee46fc_1           conda-forge/linux-64     Cached
#   + xorg-libxau                          1.0.11  hd590300_0           conda-forge/linux-64     Cached
#   + xorg-libxdmcp                         1.1.3  h7f98852_0           conda-forge/linux-64     Cached
#   + xorg-libxext                          1.3.4  h0b41bf4_2           conda-forge/linux-64     Cached
# ...
# Requirement already satisfied: packaging>=20.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from matplotlib->leafmap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from matplotlib->leafmap) (9.5.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->leafmap)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: pystac>=1.7.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from pystac-client->leafmap) (1.7.3)
# Requirement already satisfied: debugpy>=1.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (8.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (0.1.6)
# Requirement already satisfied: nest-asyncio in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (1.5.6)
# Requirement already satisfied: psutil in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (5.9.5)
# Requirement already satisfied: tornado>=6.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (6.3.2)
# Requirement already satisfied: backcall in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.2.0)
# Requirement already satisfied: decorator in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.18.2)
# Requirement already satisfied: pickleshare in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (2.15.1)
# Requirement already satisfied: setuptools>=18.5 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (67.7.2)
# Requirement already satisfied: stack-data in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jinja2>=2.9->folium<=0.13.0,>=0.11.0->leafmap) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (2023.5.7)
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached notebook-6.5.4-py3-none-any.whl (529 kB)
# Requirement already satisfied: soupsieve>1.2 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from beautifulsoup4->gdown->leafmap) (2.3.2.post1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from requests->folium<=0.13.0,>=0.11.0->leafmap) (1.7.1)
# Requirement already satisfied: Click>=6.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from whitebox->whiteboxgui>=0.6.0->leafmap) (8.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.8.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (5.3.0)
# Requirement already satisfied: pyzmq>=23.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (25.0.2)
# Requirement already satisfied: argon2-cffi in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (21.3.0)
# Requirement already satisfied: nbformat in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (5.8.0)
# Requirement already satisfied: nbconvert>=5 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (7.4.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.15.0)
# Requirement already satisfied: prometheus-client in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.16.0)
# Collecting nbclassic>=0.4.7 (from notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached nbclassic-1.0.0-py3-none-any.whl (10.0 MB)
# Requirement already satisfied: ptyprocess>=0.5 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.7.0)
# Requirement already satisfied: wcwidth in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (2.2.1)
# Requirement already satisfied: pure-eval in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0->leafmap) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0->leafmap) (3.5.1)
# Requirement already satisfied: jupyter-server>=1.8 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.2.3)
# Requirement already satisfied: bleach in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (6.0.0)
# Requirement already satisfied: defusedxml in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (1.5.0)
# Requirement already satisfied: tinycss2 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (1.2.1)
# Requirement already satisfied: fastjsonschema in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (4.17.3)
# Requirement already satisfied: argon2-cffi-bindings in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.4.4)
# Requirement already satisfied: websocket-client in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (1.5.2)
# Requirement already satisfied: cffi>=1.0.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (1.15.1)
# Requirement already satisfied: webencodings in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (1.3.0)
# Requirement already satisfied: pycparser in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (6.0)
# Requirement already satisfied: rfc3339-validator in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /workspace/.conda_envs/env_visual/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap) (0.1.1)
# Collecting fqdn (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting webcolors>=1.11 (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.4->ipywidgets<8.0.0->leafmap)
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: ipython-genutils, colour, xyzservices, whitebox, webcolors, uri-template, tzdata, traittypes, tqdm, python-box, pyshp, pyparsing, kiwisolver, jupyterlab-widgets, jsonpointer, geojson, fqdn, fonttools, filelock, cycler, contourpy, pandas, matplotlib, branca, arrow, pystac-client, isoduration, gdown, folium, nbclassic, notebook, widgetsnbextension, ipywidgets, ipytree, ipyleaflet, ipyfilechooser, ipyevents, bqplot, whiteboxgui, leafmap
# Successfully installed arrow-1.2.3 bqplot-0.12.39 branca-0.6.0 colour-0.1.5 contourpy-1.0.7 cycler-0.11.0 filelock-3.12.0 folium-0.13.0 fonttools-4.39.4 fqdn-1.5.1 gdown-4.7.1 geojson-3.0.1 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.17.2 ipython-genutils-0.2.0 ipytree-0.2.2 ipywidgets-7.7.5 isoduration-20.11.0 jsonpointer-2.3 jupyterlab-widgets-1.1.4 kiwisolver-1.4.4 leafmap-0.20.3 matplotlib-3.7.1 nbclassic-1.0.0 notebook-6.5.4 pandas-2.0.1 pyparsing-3.0.9 pyshp-2.3.1 pystac-client-0.6.1 python-box-7.0.1 tqdm-4.65.0 traittypes-0.2.1 tzdata-2023.3 uri-template-1.2.0 webcolors-1.13 whitebox-2.3.1 whiteboxgui-2.3.0 widgetsnbextension-3.6.4 xyzservices-2023.5.0

# %%
# Import liraries
from localtileserver import TileClient, get_leaflet_tile_layer
import leafmap.foliumap as leafmap

import pystac
import json
import numpy as np
import os

# Define env variables for localtileserver
os.environ["GTIFF_SRS_SOURCE"] = "EPSG"
os.environ['LOCALTILESERVER_CLIENT_PREFIX'] = 'proxy/{port}'
os.environ['PROJ_DATA'] = '/srv/conda/envs/env_visual/share/proj/'
os.environ['GDAL_DATA'] = '/srv/conda/envs/env_visual/share/gdal/'

# %% [markdown]
# Load the JSON result listing generated by `cwltool`:

# %%
with open("/workspace/workshop/07_app_package/water-bodies/outputs/out.json") as f: 
    results = json.load(f)

# %% [markdown]
# Look for the `catalog.json` file:

# %%
for item in results["stac_catalog"]["listing"]:
    
    if item['basename'] == "catalog.json":
        catalog = pystac.read_file(item["path"])
        break

# %% [markdown]
# List the contents of the STAC Catalog

# %%
catalog.describe()
# Out:
# * <Catalog id=catalog>
#   * <Item id=S2B_10TFK_20210713_0_L2A>
#   * <Item id=S2A_10TFK_20220524_0_L2A>

# %%
it1 = catalog.get_item('S2B_10TFK_20210713_0_L2A')
it1
# Out:
# <Item id=S2B_10TFK_20210713_0_L2A>

# %%
it1.properties
# Out:
# {'proj:epsg': 32610,
#  'proj:geometry': {'type': 'Polygon',
#   'coordinates': [[[635710.0, 4411780.0],
#     [693380.0, 4411780.0],
#     [693380.0, 4481380.0],
#     [635710.0, 4481380.0],
#     [635710.0, 4411780.0]]]},
#  'proj:bbox': [635710.0, 4411780.0, 693380.0, 4481380.0],
#  'proj:shape': [6960, 5767],
#  'proj:transform': [10.0, 0.0, 635710.0, 0.0, -10.0, 4481380.0, 0.0, 0.0, 1.0],
#  'proj:projjson': {'$schema': 'https://proj.org/schemas/v0.4/projjson.schema.json',
#   'type': 'ProjectedCRS',
#   'name': 'WGS 84 / UTM zone 10N',
#   'base_crs': {'name': 'WGS 84',
#    'datum': {'type': 'GeodeticReferenceFrame',
#     'name': 'World Geodetic System 1984',
#     'ellipsoid': {'name': 'WGS 84',
#      'semi_major_axis': 6378137,
#      'inverse_flattening': 298.257223563}},
#    'coordinate_system': {'subtype': 'ellipsoidal',
#     'axis': [{'name': 'Geodetic latitude',
#       'abbreviation': 'Lat',
#       'direction': 'north',
#       'unit': 'degree'},
#      {'name': 'Geodetic longitude',
#       'abbreviation': 'Lon',
#       'direction': 'east',
#       'unit': 'degree'}]},
#    'id': {'authority': 'EPSG', 'code': 4326}},
#   'conversion': {'name': 'UTM zone 10N',
#    'method': {'name': 'Transverse Mercator',
#     'id': {'authority': 'EPSG', 'code': 9807}},
#    'parameters': [{'name': 'Latitude of natural origin',
#      'value': 0,
#      'unit': 'degree',
#      'id': {'authority': 'EPSG', 'code': 8801}},
#     {'name': 'Longitude of natural origin',
#      'value': -123,
#      'unit': 'degree',
#      'id': {'authority': 'EPSG', 'code': 8802}},
#     {'name': 'Scale factor at natural origin',
#      'value': 0.9996,
#      'unit': 'unity',
#      'id': {'authority': 'EPSG', 'code': 8805}},
#     {'name': 'False easting',
#      'value': 500000,
#      'unit': 'metre',
#      'id': {'authority': 'EPSG', 'code': 8806}},
#     {'name': 'False northing',
#      'value': 0,
#      'unit': 'metre',
#      'id': {'authority': 'EPSG', 'code': 8807}}]},
#   'coordinate_system': {'subtype': 'Cartesian',
#    'axis': [{'name': 'Easting',
#      'abbreviation': '',
#      'direction': 'east',
#      'unit': 'metre'},
#     {'name': 'Northing',
#      'abbreviation': '',
#      'direction': 'north',
#      'unit': 'metre'}]},
#   'id': {'authority': 'EPSG', 'code': 32610}},
#  'datetime': '2021-07-13T19:03:24Z'}

# %%
m = leafmap.Map()

for item in catalog.get_all_items():
    m.add_raster(item.get_assets()["data"].get_absolute_href(), layer_name=item.id) #, crs="EPSG:32610")

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c76b10f3b8654dccbc4034d1c875760e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c76b10f3b8654dccbc4034d1c875760e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c76b10f3b8654dccbc4034d1c875760e = L.map(
#                 &quot;map_c76b10f3b8654dccbc4034d1c875760e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_c76b10f3b8654dccbc4034d1c875760e);
#
#
#
#
#
#             var tile_layer_681f17af6b0a9b315366ad26a021c840 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c76b10f3b8654dccbc4034d1c875760e);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_c76b10f3b8654dccbc4034d1c875760e);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_c76b10f3b8654dccbc4034d1c875760e
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_b7e1b6ffff11c218a624a06a7083ad57 = new L.Control.Draw(
#                 options
#             ).addTo( map_c76b10f3b8654dccbc4034d1c875760e );
#             map_c76b10f3b8654dccbc4034d1c875760e.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_c76b10f3b8654dccbc4034d1c875760e.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_cdb2244c381fdf627aee80bd3f7866f2 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_c76b10f3b8654dccbc4034d1c875760e.addControl(measure_control_cdb2244c381fdf627aee80bd3f7866f2);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_c76b10f3b8654dccbc4034d1c875760e.setView(e.geocode.center, 11);
#             }).addTo(map_c76b10f3b8654dccbc4034d1c875760e);
#
#
#
#             map_c76b10f3b8654dccbc4034d1c875760e.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_dadb8f92e420f9bf8fae317401498a90 = L.tileLayer(
#                 &quot;/proxy/45213/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fworkspace%2Fworkshop%2F07_app_package%2Fwater-bodies%2Foutputs%2FS2B_10TFK_20210713_0_L2A%2Fotsu.tif\u0026n_colors=255\u0026projection=EPSG%3A3857&quot;,
#                 {&quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 100, &quot;maxZoom&quot;: 100, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&q
